# %%
import pandas as pd

# %% [markdown]
# ### austine animal center 입소 데이터

# %%
income = pd.read_csv('./datasets/Austin_Animal_Center_Intakes.csv')

# %%
income.describe()
# Out:
#        Animal ID    Name                DateTime  MonthYear Found Location  \
# count     165041  117472                  165041     165041         165041
# unique    148237   28666                  114002        130          67169
# top      A721033    Luna  09/23/2016 12:00:00 PM  June 2015    Austin (TX)
# freq          33     710                      64       2189          30108
#
#        Intake Type Intake Condition Animal Type Sex upon Intake  \
# count       165041           165041      165041          165039
# unique           6               20           5               5
# top          Stray           Normal         Dog     Intact Male
# freq        113195           140418       90634           55774
#
#        Age upon Intake                   Breed        Color
# count           165040                  165041       165041
# unique              55                    2949          649
# top             1 year  Domestic Shorthair Mix  Black/White
# ...

# %%
income_tuned = income[['MonthYear', 'Intake Type', 'Animal Type']]

# %%
income_tuned.
# Out:
#              MonthYear      Intake Type Animal Type
# 0         October 2013            Stray         Cat
# 1         October 2013            Stray         Cat
# 2         October 2013            Stray         Dog
# 3         October 2013            Stray         Dog
# 4         October 2013  Owner Surrender         Dog
# ...                ...              ...         ...
# 165036  September 2023  Owner Surrender         Dog
# 165037        May 2024            Stray         Cat
# 165038       June 2024            Stray         Dog
# 165039      April 2024            Stray         Cat
# 165040        May 2024  Owner Surrender         Dog
#
# [165041 rows x 3 columns]
